# %%
#transporting necessary package

import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("Raga Brindabani Sarang.csv")

# %%
print(df.head())
# Out:
#                 Song Name   P(S)=X1  P(r )=X2   P(R)=X3  P(g)=X4  P(G)=X5  \
# 0  Raga Brindabani Sarang  0.023529         0  0.152941        0        0
#
#     P(M)=X6  P(m)=X7   P(P)=X8  P(d)=X9  P(D)=X10  P(n)=X11  P(N)=X12
# 0  0.188235        0  0.211765        0         0  0.070588  0.141176

# %%
x=pd.plotting.andrews_curves(df,'Song Name', color="Black")
